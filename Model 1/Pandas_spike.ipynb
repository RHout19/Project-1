# %%
# Import pandas library
import pandas as pd

# %%
# Creating the Series from a list
cat1 = ['Grumpy Cat', 'cat', 2012]

ser = pd.Series(cat1)

print(ser)
# Out:
# 0    Grumpy Cat
# 1           cat
# 2          2012
# dtype: object

# %%
# Create the index
cat_index = ['name', 'species', 'YOB']

# Set the index
ser.index = cat_index
print(ser)
# Out:
# name       Grumpy Cat
# species           cat
# YOB              2012
# dtype: object

# %%
# Creating a DataFrame from a list
name = ['Grumpy Cat', 'Garfi the Angry Cat', 'Colonel Meow']
species = ['cat','cat', 'cat']
YOB = [2004, 2012, 2011]

# %%
# Creating the Series from a dictionary
cat_dict= {	'name':name,
   	        'species':species, 
            'YOB': YOB}
            
df = pd.DataFrame(cat_dict)
df
# Out:
#                   name species   YOB
# 0           Grumpy Cat     cat  2004
# 1  Garfi the Angry Cat     cat  2012
# 2         Colonel Meow     cat  2011

# %%
df
# Out:
#                   name species   YOB
# 0           Grumpy Cat     cat  2004
# 1  Garfi the Angry Cat     cat  2012
# 2         Colonel Meow     cat  2011

# %%
df["name"]
# Out:
# 0             Grumpy Cat
# 1    Garfi the Angry Cat
# 2           Colonel Meow
# Name: name, dtype: object

# %%
df[["species", "YOB"]]
# Out:
#   species   YOB
# 0     cat  2004
# 1     cat  2012
# 2     cat  2011

# %%
df[0:2]
# Out:
#                   name species   YOB
# 0           Grumpy Cat     cat  2004
# 1  Garfi the Angry Cat     cat  2012

# %%
# .loc function is label based.
df.loc[0:2,["name","species"]]
# Out:
#                   name species   YOB
# 0           Grumpy Cat     cat  2004
# 1  Garfi the Angry Cat     cat  2012

# %%
# .iloc function is integer based.
# In this example, we are selecting the first two rows (0:2) and all the columns (:)

df.iloc[0:2,[0,2]]
# Out:
#                   name   YOB
# 0           Grumpy Cat  2004
# 1  Garfi the Angry Cat  2012

# %%
# .iloc function is integer based.
# In this example, we are selecting the first and second rows (0,2) and the first and second columns (0,2)

display(df.iloc[[0,2],[0,2]])
# Out:
#            name   YOB
# 0    Grumpy Cat  2004
# 2  Colonel Meow  2011

# %%
# You can use .head() to see the first 5 rows. You can also specify a custom number of rows to see by specifying it in the parantheses .head(11)
df.head(5)
# Out:
#                   name species   YOB
# 0           Grumpy Cat     cat  2004
# 1  Garfi the Angry Cat     cat  2012
# 2         Colonel Meow     cat  2011

# %%
# You can use .tail() to see the last 5 rows. You can also specify a custom number of rows to see by specifying it in the parantheses .tail(11)

df.tail()
# Out:
#                   name species   YOB
# 0           Grumpy Cat     cat  2004
# 1  Garfi the Angry Cat     cat  2012
# 2         Colonel Meow     cat  2011

# %%
df = pd.read_csv("/Users/elysium/Documents/01_Code_Academy/03 - Pandas/movies_2.csv")

# %%
movies = df
for x in movies:
    display(x)
# Out:
# 'MovieID'
# 'Title'
# 'MPAA Rating'
# 'Budget'
# 'Gross'
# 'Release Date'
# 'Genre'
# 'Runtime'
# 'Rating'
# 'Rating Count'
# 'Summary'

# %%
movies.head()
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# 2  Det. Scott Turner (Tom Hanks) is an uptight, b...
# 3  The biography of Ron Kovic. Paralyzed in the V...
# 4  An Iowa corn farmer, hearing voices, interpret...

# %%
movies.tail()
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
#             Gross Release Date      Genre  Runtime  Rating  Rating Count  \
# 611  1.062000e+09   2019-06-11  Animation    100.0     NaN           NaN
# 612  7.594000e+08   2019-07-13   Thriller    136.0     NaN           NaN
# 613  1.632000e+09   2019-07-09      Drama    118.0     NaN           NaN
# 614  2.796000e+09   2019-04-22     Action    181.0     NaN           NaN
# 615           NaN          NaN        NaN      NaN     NaN           NaN
#
#     Summary
# 611     NaN
# 612     NaN
# 613     NaN
# 614     NaN
# 615     NaN

# %%
movies_sorted = movies.sort_values(by=["Title"])
movies_sorted.head()
# Out:
#      MovieID             Title MPAA Rating       Budget        Gross  \
# 149      150    101 Dalmatians           G   54000000.0  320689294.0
# 281      282  2 Fast 2 Furious       PG-13   76000000.0  236350661.0
# 413      414              2012       PG-13  200000000.0  769653595.0
# 496      497    22 Jump Street           R   50000000.0  188441614.0
# 359      360               300           R   60000000.0  454161935.0
#
#     Release Date      Genre  Runtime  Rating  Rating Count  \
# 149   1996-11-17     Comedy    103.0     5.7       94582.0
# 281   2003-06-05   Thriller    107.0     5.9      236645.0
# 413   2009-10-10  Adventure    158.0     4.3       28949.0
# 496   2014-06-05     Comedy    112.0     7.0      325958.0
# 359   2007-03-09     Action    155.0     8.1      681249.0
#
#                                                Summary
# 149  An evil high-fashion designer plots to steal D...
# 281  Former cop Brian OConner is called upon to bus...
# 413                                                NaN
# 496  After making their way through high school (tw...
# 359                                                NaN

# %%
# Use .shape to see the total rows x columns in a dataframe.
movies.shape
# Out:
# (616, 11)

# %%
# Use .describe to calculate statistical data.
movies.describe()
# Out:
#           MovieID        Budget         Gross     Runtime      Rating  \
# count  616.000000  6.150000e+02  6.150000e+02  615.000000  508.000000
# mean   307.500000  9.491710e+07  4.453221e+08  118.642276    6.917323
# std    177.968162  6.748114e+07  3.394075e+08   22.252376    0.888928
# min      0.000000  6.000000e+04  5.300000e+07   79.000000    4.100000
# 25%    153.750000  4.000000e+07  2.158939e+08  102.000000    6.400000
# 50%    307.500000  8.000000e+07  3.510404e+08  117.000000    6.900000
# 75%    461.250000  1.400000e+08  5.851766e+08  132.000000    7.600000
# max    615.000000  4.000000e+08  2.796000e+09  201.000000    9.000000
#
#        Rating Count
# count  5.080000e+02
# mean   3.392521e+05
# std    3.213388e+05
# min    1.491800e+04
# 25%    1.275922e+05
# 50%    2.403475e+05
# 75%    4.257000e+05
# max    2.127228e+06

# %%
# .info() function is used to get a summary of the dataframe and it's types, and the number of non-null values.

movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   MovieID          616 non-null    int64
#  1   Title            615 non-null    object
#  2   MPAA Rating      615 non-null    object
#  3   Budget           615 non-null    float64
#  4   Gross            615 non-null    float64
#  5   Release Date     615 non-null    datetime64[ns]
#  6   Genre            615 non-null    object
#  7   Runtime          615 non-null    float64
#  8   Rating           508 non-null    float64
#  9   Rating Count     508 non-null    float64
#  10  Summary          496 non-null    object
#  11  Day of the week  615 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(5)
# memory usage: 57.9+ KB

# %%
movies.tail(10)
# Out:
#      MovieID                                  Title MPAA Rating       Budget  \
# 606      607              Spider-Man: Far from Home       PG-13  160000000.0
# 607      608                                  Dumbo          PG  170000000.0
# 608      609                         Captain Marvel       PG-13  175000000.0
# 609      610                                Aladdin          PG  183000000.0
# 610      611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
#             Gross Release Date      Genre  Runtime  Rating  Rating Count  \
# 606  1.131000e+09   2019-06-26     Action    129.0     NaN           NaN
# 607  3.530000e+08   2019-03-11  Adventure    112.0     NaN           NaN
# 608  1.128000e+09   2019-02-27     Action    124.0     NaN           NaN
# 609  1.049000e+09   2019-05-08    Fantasy    128.0     NaN           NaN
# 610  3.859000e+08   2019-05-13  Adventure    132.0     NaN           NaN
# 611  1.062000e+09   2019-06-11  Animation    100.0     NaN           NaN
# 612  7.594000e+08   2019-07-13   Thriller    136.0     NaN           NaN
# 613  1.632000e+09   2019-07-09      Drama    118.0     NaN           NaN
# 614  2.796000e+09   2019-04-22     Action    181.0     NaN           NaN
# 615           NaN          NaN        NaN      NaN     NaN           NaN
#
#     Summary
# 606     NaN
# 607     NaN
# 608     NaN
# 609     NaN
# 610     NaN
# 611     NaN
# 612     NaN
# 613     NaN
# 614     NaN
# 615     NaN

# %%
# .isna() detects null values. 
# Combine it with .sum() and you can get a total number of null values in a large DF

movies.isna()
# Out:
#      MovieID  Title  MPAA Rating  Budget  Gross  Release Date  Genre  Runtime  \
# 0      False  False        False   False  False         False  False    False
# 1      False  False        False   False  False         False  False    False
# 2      False  False        False   False  False         False  False    False
# 3      False  False        False   False  False         False  False    False
# 4      False  False        False   False  False         False  False    False
# ..       ...    ...          ...     ...    ...           ...    ...      ...
# 611    False  False        False   False  False         False  False    False
# 612    False  False        False   False  False         False  False    False
# 613    False  False        False   False  False         False  False    False
# 614    False  False        False   False  False         False  False    False
# 615    False   True         True    True   True          True   True     True
#
#      Rating  Rating Count  Summary
# 0     False         False    False
# 1     False         False    False
# 2     False         False    False
# 3     False         False    False
# 4     False         False    False
# ..      ...           ...      ...
# 611    True          True     True
# 612    True          True     True
# 613    True          True     True
# 614    True          True     True
# 615    True          True     True
#
# [616 rows x 11 columns]

# %%
# .dtypes returns a series with the data type of each column.
movies.dtypes
# Out:
# MovieID                     int64
# Title                      object
# MPAA Rating                object
# Budget                    float64
# Gross                     float64
# Release Date       datetime64[ns]
# Genre                      object
# Runtime                   float64
# Rating                    float64
# Rating Count              float64
# Summary                    object
# Day of the week            object
# dtype: object

# %%
movies.head(1)
# Out:
#    MovieID               Title MPAA Rating     Budget        Gross  \
# 0        1  Look Who's Talking       PG-13  7500000.0  296000000.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...

# %%
# The Release Date is an object, a string type. We can convert this to a date format using .to_datetime()

movies["Release Date"] = pd.to_datetime(movies["Release Date"], format = "%Y/%m/%d")
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       616 non-null    int64
#  1   Title         615 non-null    object
#  2   MPAA Rating   615 non-null    object
#  3   Budget        615 non-null    float64
#  4   Gross         615 non-null    float64
#  5   Release Date  615 non-null    datetime64[ns]
#  6   Genre         615 non-null    object
#  7   Runtime       615 non-null    float64
#  8   Rating        508 non-null    float64
#  9   Rating Count  508 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(4)
# memory usage: 53.1+ KB

# %%
# Create new column called day of the week. 
movies["Day of the week"] = movies["Release Date"].dt.day_name
movies.head(15)
# Out:
#     MovieID                                  Title MPAA Rating      Budget  \
# 0         1                     Look Who's Talking       PG-13   7500000.0
# 1         2                     Driving Miss Daisy          PG   7500000.0
# 2         3                         Turner & Hooch          PG  13000000.0
# 3         4             Born on the Fourth of July           R  14000000.0
# 4         5                        Field of Dreams          PG  15000000.0
# 5         6                             Uncle Buck          PG  15000000.0
# 6         7                When Harry Met Sally...           R  16000000.0
# 7         8                     Dead Poets Society          PG  16400000.0
# 8         9                             Parenthood       PG-13  20000000.0
# 9        10                        Lethal Weapon 2           R  25000000.0
# 10       11                   The War of the Roses           R  26000000.0
# 11       12  National Lampoon's Christmas Vacation       PG-13  27000000.0
# 12       13               Honey, I Shrunk the Kids          PG  32000000.0
# 13       14                                 Batman          PG  35000000.0
# 14       15                        Ghostbusters II          PG  37000000.0
#
#           Gross Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   296000000.0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   145793296.0   1989-12-13   Comedy     99.0     7.4       91075.0
# 2    71079915.0   1989-07-28    Crime    100.0     7.2       91415.0
# 3   161001698.0   1989-12-20      War    145.0     7.2       91415.0
# 4    84431625.0   1989-04-21    Drama    107.0     7.5      101702.0
# 5    79258538.0   1989-08-16   Family    100.0     7.0       77659.0
# 6    92800000.0   1989-07-21  Romance     96.0     7.6      180871.0
# 7   235860116.0   1989-06-02    Drama    129.0     8.1      382002.0
# 8   126297830.0   1989-07-31   Comedy    124.0     7.0       41866.0
# 9   227853986.0   1989-07-07   Comedy    114.0     7.2      151737.0
# 10  160200000.0   1989-12-08   Comedy    116.0     6.8       45248.0
# 11   71320000.0   1989-12-01   Action     97.0     7.6      135690.0
# 12  222724172.0   1989-06-22   Family     93.0     6.3      132480.0
# 13  411348924.0   1989-06-23   Action    126.0     7.5      319517.0
# 14  215394738.0   1989-06-15   Comedy    108.0     6.6      171196.0
#
#                                               Summary Day of the week
# 0   After a single, career-minded woman is left on...        Thursday
# 1   An old Jewish woman and her African-American c...       Wednesday
# 2   Det. Scott Turner (Tom Hanks) is an uptight, b...          Friday
# 3   The biography of Ron Kovic. Paralyzed in the V...       Wednesday
# 4   An Iowa corn farmer, hearing voices, interpret...          Friday
# 5   Bachelor and all-round slob Buck babysits his ...       Wednesday
# 6   Harry and Sally have known each other for year...          Friday
# 7   English teacher John Keating inspires his stud...          Friday
# 8   The Buckmans are a midwestern family all deali...          Monday
# 9   Riggs and Murtaugh are on the trail of South A...          Friday
# 10  A married couple try everything to get each ot...          Friday
# 11  The Griswold familys plans for a big family Ch...          Friday
# 12  The scientist father of a teenage girl and boy...        Thursday
# 13  The Dark Knight of Gotham City begins his war ...          Friday
# 14  The discovery of a massive river of ectoplasm ...        Thursday

# %%
runtime = movies[movies["Runtime"] < 100]
runtime.head(
    
)
# Out:
#     MovieID                                  Title MPAA Rating      Budget  \
# 0         1                     Look Who's Talking       PG-13   7500000.0
# 1         2                     Driving Miss Daisy          PG   7500000.0
# 6         7                When Harry Met Sally...           R  16000000.0
# 11       12  National Lampoon's Christmas Vacation       PG-13  27000000.0
# 12       13               Honey, I Shrunk the Kids          PG  32000000.0
#
#           Gross Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   296000000.0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   145793296.0   1989-12-13   Comedy     99.0     7.4       91075.0
# 6    92800000.0   1989-07-21  Romance     96.0     7.6      180871.0
# 11   71320000.0   1989-12-01   Action     97.0     7.6      135690.0
# 12  222724172.0   1989-06-22   Family     93.0     6.3      132480.0
#
#                                               Summary Day of the week
# 0   After a single, career-minded woman is left on...        Thursday
# 1   An old Jewish woman and her African-American c...       Wednesday
# 6   Harry and Sally have known each other for year...          Friday
# 11  The Griswold familys plans for a big family Ch...          Friday
# 12  The scientist father of a teenage girl and boy...        Thursday

# %%
movies[(movies["Release Date"] < "1994-07-14") & (movies["Genre"] == "Action")]
# Out:
#      MovieID                                  Title MPAA Rating      Budget  \
# 11        12  National Lampoon's Christmas Vacation       PG-13  27000000.0
# 13        14                                 Batman          PG  35000000.0
# 18        19                           Tango & Cash           R  55000000.0
# 21        22           Teenage Mutant Ninja Turtles          PG  13500000.0
# 23        24                       Kindergarten Cop       PG-13  15000000.0
# 33        34                        Another 48 Hrs.           R  38000000.0
# 45        46        Teenage Mutant Ninja Turtles II          PG  25000000.0
# 64        65                          The Bodyguard           R  25000000.0
# 69        70                        Lethal Weapon 3           R  35000000.0
# 70        71                            Under Siege           R  35000000.0
# 73        74               The Last of the Mohicans           R  40000000.0
# 78        79                         Batman Returns       PG-13  80000000.0
# 96        97                         Demolition Man           R  57000000.0
# 104      105                                  Speed           R  30000000.0
# 117      118                               Maverick          PG  75000000.0
#
#            Gross Release Date   Genre  Runtime  Rating  Rating Count  \
# 11    71320000.0   1989-12-01  Action     97.0     7.6      135690.0
# 13   411348924.0   1989-06-23  Action    126.0     7.5      319517.0
# 18    63408614.0   1989-12-22  Action    104.0     6.8       79806.0
# 21   202000000.0   1990-03-30  Action     93.0     6.8       79806.0
# 23   201957688.0   1990-12-21  Action    111.0     6.1      127793.0
# 33   153518974.0   1990-06-08  Action     95.0     5.9       36103.0
# 45    78600000.0   1991-03-22  Action     88.0     8.0      397467.0
# 64   411006740.0   1992-11-25  Action    129.0     6.3      110511.0
# 69   321731527.0   1992-05-15  Action    118.0     6.7      148440.0
# 70   156563139.0   1992-10-08  Action    103.0     6.5       71962.0
# 73    75505856.0   1992-09-25  Action    112.0     7.7      139000.0
# 78   280000000.0   1992-06-19  Action    126.0     7.0      258216.0
# 96   159055768.0   1993-10-08  Action    115.0     6.7      148329.0
# 104  350448145.0   1994-06-09  Action    116.0     7.2      309338.0
# 117  183000000.0   1994-05-20  Action    127.0     7.0       96405.0
#
#                                                Summary Day of the week
# 11   The Griswold familys plans for a big family Ch...          Friday
# 13   The Dark Knight of Gotham City begins his war ...          Friday
# 18   Framed by their ruthless arch-nemesis, a misma...          Friday
# 21   Four teenage mutant ninja turtles emerge from ...          Friday
# 23   A tough cop must pose as a kindergarten teache...          Friday
# 33   Jack Cates once again enlists the aid of ex-co...          Friday
# 45   The Turtles and the Shredder battle once again...          Friday
# 64   A former Secret Service agent takes on the job...       Wednesday
# 69   Martin Riggs and Roger Murtaugh pursue a forme...          Friday
# 70   An ex-Navy Seal turned cook is the only person...        Thursday
# 73   Three trappers protect the daughters of a Brit...          Friday
# 78   Batman returns to the big screen when a deform...          Friday
# 96   A police officer is brought out of suspended a...          Friday
# 104  A young police officer must prevent a bomb exp...        Thursday
# 117  Bret Maverick, needing money for a poker tourn...          Friday

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 616 entries, 0 to 615
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MovieID       616 non-null    int64
#  1   Title         615 non-null    object
#  2   MPAA Rating   615 non-null    object
#  3   Budget        615 non-null    float64
#  4   Gross         615 non-null    float64
#  5   Release Date  615 non-null    object
#  6   Genre         615 non-null    object
#  7   Runtime       615 non-null    float64
#  8   Rating        508 non-null    float64
#  9   Rating Count  508 non-null    float64
#  10  Summary       496 non-null    object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 53.1+ KB

# %%
movies_test = movies[(movies["MPAA Rating"] == "PG")]

# %%
movies_test.head()
# Out:
#    MovieID               Title MPAA Rating      Budget        Gross  \
# 1        2  Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3      Turner & Hooch          PG  13000000.0   71079915.0
# 4        5     Field of Dreams          PG  15000000.0   84431625.0
# 5        6          Uncle Buck          PG  15000000.0   79258538.0
# 7        8  Dead Poets Society          PG  16400000.0  235860116.0
#
#   Release Date   Genre  Runtime  Rating  Rating Count  \
# 1   1989-12-13  Comedy     99.0     7.4       91075.0
# 2   1989-07-28   Crime    100.0     7.2       91415.0
# 4   1989-04-21   Drama    107.0     7.5      101702.0
# 5   1989-08-16  Family    100.0     7.0       77659.0
# 7   1989-06-02   Drama    129.0     8.1      382002.0
#
#                                              Summary
# 1  An old Jewish woman and her African-American c...
# 2  Det. Scott Turner (Tom Hanks) is an uptight, b...
# 4  An Iowa corn farmer, hearing voices, interpret...
# 5  Bachelor and all-round slob Buck babysits his ...
# 7  English teacher John Keating inspires his stud...

# %%
movies["MPAA Rating"] == "PG"
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 611    False
# 612    False
# 613     True
# 614    False
# 615    False
# Name: MPAA Rating, Length: 616, dtype: bool

# %%
movies.head()
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# 2  Det. Scott Turner (Tom Hanks) is an uptight, b...
# 3  The biography of Ron Kovic. Paralyzed in the V...
# 4  An Iowa corn farmer, hearing voices, interpret...

# %%
result = pd.DataFrame()
for x in movies:
    
    if x["MPAA Rating"] == "PG":
        # print(x.index())
        print(x)
        # result = movies.concat["Title"]

display(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [74], line 4
#       1 result = pd.DataFrame()
#       2 for x in movies:
# ----> 4     if x["MPAA Rating"] == "PG":
#       5         # print(x.index())
#       6         print(x)
#       7         # result = movies.concat["Title"]
#
# TypeError: string indices must be integers

# %%
df_test = movies[["Title", "Release Date"]]

# %%
df_test
# Out:
#                                      Title Release Date
# 0                       Look Who's Talking   1989-10-12
# 1                       Driving Miss Daisy   1989-12-13
# 2                           Turner & Hooch   1989-07-28
# 3               Born on the Fourth of July   1989-12-20
# 4                          Field of Dreams   1989-04-21
# ..                                     ...          ...
# 611                            Toy Story 4   2019-06-11
# 612  Fast & Furious Presents: Hobbs & Shaw   2019-07-13
# 613                          The Lion King   2019-07-09
# 614                      Avengers: Endgame   2019-04-22
# 615                                    NaN          NaN
#
# [616 rows x 2 columns]

# %%
for index, row in movies.iterrows():
    print(row["Title"], row["Release Date"])
# Out:
